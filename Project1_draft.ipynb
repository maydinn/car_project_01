# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('police.csv')
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
df_copy = df.copy()

# %%
df_copy.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
df_copy.shape
# Out:
# (509681, 26)

# %%
df_copy.dropna(inplace=True, axis=1)

# %%
df_copy.shape
# Out:
# (509681, 6)

# %%
df_copy.isnull().sum()
# Out:
# id                    0
# state                 0
# location_raw          0
# contraband_found      0
# drugs_related_stop    0
# district              0
# dtype: int64

# %%
df_copy['driver_gender'] = df['driver_gender']

# %%
df_copy.isnull().sum()
# Out:
# id                        0
# state                     0
# location_raw              0
# contraband_found          0
# drugs_related_stop        0
# district                  0
# driver_gender         29097
# dtype: int64

# %%
df_copy.dropna(inplace=True, axis=0)

# %%
df_copy.shape
# Out:
# (480584, 7)

# %%
df['is_arrested'].head()
# Out:
# 0    False
# 1    False
# 2      NaN
# 3    False
# 4    False
# Name: is_arrested, dtype: object

# %%
type(df.is_arrested[0])
# Out:
# bool

# %%
df.is_arrested = df.is_arrested.astype('bool')

# %%
type(df.is_arrested)
# Out:
# pandas.core.series.Series

# %%
df.is_arrested.dtype
# Out:
# dtype('bool')

# %%
df.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
df['stop_daytime'] = df.stop_date + " " +df.stop_time

# %%
df.head()
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_daytime
# 2005-01-02 01:55:00  RI-2005-00001    RI  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002    RI  2005-01-02     20:30      Zone X4
# 2005-01-04 11:30:00  RI-2005-00003    RI  2005-01-04     11:30      Zone X1
# 2005-01-04 12:55:00  RI-2005-00004    RI  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005    RI  2005-01-06     01:30      Zone X4
#
#                      county_name  county_fips  fine_grained_location  \
# stop_daytime
# 2005-01-02 01:55:00          NaN          NaN                    NaN
# 2005-01-02 20:30:00          NaN          NaN                    NaN
# 2005-01-04 11:30:00          NaN          NaN                    NaN
# 2005-01-04 12:55:00          NaN          NaN                    NaN
# 2005-01-06 01:30:00          NaN          NaN                    NaN
#
# ...

# %%
df['stop_daytime']=pd.to_datetime(df['stop_daytime'])

# %%
type(df.stop_daytime[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_type_raw  search_type contraband_found stop_outcome is_arrested  \
# ...

# %%
df.set_index('stop_daytime', inplace=True)

# %%
df.head()
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_daytime
# 2005-01-02 01:55:00  RI-2005-00001    RI  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002    RI  2005-01-02     20:30      Zone X4
# 2005-01-04 11:30:00  RI-2005-00003    RI  2005-01-04     11:30      Zone X1
# 2005-01-04 12:55:00  RI-2005-00004    RI  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005    RI  2005-01-06     01:30      Zone X4
#
#                      county_name  county_fips  fine_grained_location  \
# stop_daytime
# 2005-01-02 01:55:00          NaN          NaN                    NaN
# 2005-01-02 20:30:00          NaN          NaN                    NaN
# 2005-01-04 11:30:00          NaN          NaN                    NaN
# 2005-01-04 12:55:00          NaN          NaN                    NaN
# 2005-01-06 01:30:00          NaN          NaN                    NaN
#
# ...

# %%
df['violation'].unique()
# Out:
# array(['Speeding', nan, 'Equipment', 'Other', 'Moving violation',
#        'Registration/plates', 'Seat belt'], dtype=object)

# %%
df['violation'].value_counts()
# Out:
# Speeding               268744
# Moving violation        90234
# Equipment               61252
# Other                   24221
# Registration/plates     19830
# Seat belt               16327
# Name: violation, dtype: int64

# %%
total = df['violation'].count()

# %%
for i in range(len(df['violation'].value_counts())):
    print(df['violation'].unique()[i],'{:.2f}%'.format(df['violation'].value_counts()[i]/total))
# Out:
# Speeding 0.56%
# nan 0.19%
# Equipment 0.13%
# Other 0.05%
# Moving violation 0.04%
# Registration/plates 0.03%

# %%
df_f = df[df['driver_gender'] == 'F']

# %%
df_f.head()
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_daytime
# 2005-02-24 01:20:00  RI-2005-00016    RI  2005-02-24     01:20      Zone X3
# 2005-03-14 10:00:00  RI-2005-00019    RI  2005-03-14     10:00      Zone K3
# 2005-03-29 23:20:00  RI-2005-00026    RI  2005-03-29     23:20      Zone K3
# 2005-06-06 13:20:00  RI-2005-00035    RI  2005-06-06     13:20      Zone X4
# 2005-06-18 16:30:00  RI-2005-00037    RI  2005-06-18     16:30      Zone X4
#
#                      county_name  county_fips  fine_grained_location  \
# stop_daytime
# 2005-02-24 01:20:00          NaN          NaN                    NaN
# 2005-03-14 10:00:00          NaN          NaN                    NaN
# 2005-03-29 23:20:00          NaN          NaN                    NaN
# 2005-06-06 13:20:00          NaN          NaN                    NaN
# 2005-06-18 16:30:00          NaN          NaN                    NaN
#
# ...

# %%
df_M = df[df['driver_gender'] == 'M']

# %%
total_f = df_f['violation'].count()
for i in range(len(df_f['violation'].value_counts())):
    print(df_f['violation'].unique()[i],'{:.2f}'.format(df_f['violation'].value_counts()[i]/total_f))
# Out:
# Speeding 0.66
# Moving violation 0.14
# Equipment 0.11
# Registration/plates 0.04
# Other 0.03
# Seat belt 0.03

# %%
total_m = df_M['violation'].count()
for i in range(len(df_M['violation'].value_counts())):
    print(df_M['violation'].unique()[i],'{:.2f}'.format(df_M['violation'].value_counts()[i]/total_m))
# Out:
# Speeding 0.52
# Equipment 0.21
# Other 0.14
# Moving violation 0.06
# Registration/plates 0.04
# Seat belt 0.04

# %%
df_f_speed = df[(df['driver_gender'] == 'F') & (df['violation'] =='Speeding')]

# %%
df_f_speed.head()
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_daytime
# 2005-02-24 01:20:00  RI-2005-00016    RI  2005-02-24     01:20      Zone X3
# 2005-03-14 10:00:00  RI-2005-00019    RI  2005-03-14     10:00      Zone K3
# 2005-03-29 23:20:00  RI-2005-00026    RI  2005-03-29     23:20      Zone K3
# 2005-06-06 13:20:00  RI-2005-00035    RI  2005-06-06     13:20      Zone X4
# 2005-07-06 11:22:00  RI-2005-00038    RI  2005-07-06     11:22      Zone X1
#
#                      county_name  county_fips  fine_grained_location  \
# stop_daytime
# 2005-02-24 01:20:00          NaN          NaN                    NaN
# 2005-03-14 10:00:00          NaN          NaN                    NaN
# 2005-03-29 23:20:00          NaN          NaN                    NaN
# 2005-06-06 13:20:00          NaN          NaN                    NaN
# 2005-07-06 11:22:00          NaN          NaN                    NaN
#
# ...

# %%
df_m_speed = df[(df['driver_gender'] == 'M') & (df['violation'] =='Speeding')]

# %%
total_f_speed = df_f_speed['stop_outcome'].count()
for i in range(len(df_f_speed['stop_outcome'].value_counts())):
    print(df_f_speed['stop_outcome'].unique()[i],'{:.2f}'.format(df_f_speed['stop_outcome'].value_counts()[i]/total_f_speed))
# Out:
# Citation 0.95
# Warning 0.04
# Arrest Passenger 0.01
# Arrest Driver 0.00
# N/D 0.00
# No Action 0.00

# %%
total_m_speed = df_m_speed['stop_outcome'].count()
for i in range(len(df_m_speed['stop_outcome'].value_counts())):
    print(df_m_speed['stop_outcome'].unique()[i],'{:.2f}'.format(df_m_speed['stop_outcome'].value_counts()[i]/total_m_speed))
# Out:
# Citation 0.94
# Arrest Driver 0.04
# Warning 0.02
# No Action 0.00
# Arrest Passenger 0.00
# N/D 0.00

# %%
type(df['search_conducted'][0])
# Out:
# bool

# %%
# Out:
# numpy.int64

# %%
df['search_conducted'].astype('bool')
# Out:
# stop_daytime
# 2005-01-02 01:55:00    False
# 2005-01-02 20:30:00    False
# 2005-01-04 11:30:00    False
# 2005-01-04 12:55:00    False
# 2005-01-06 01:30:00    False
#                        ...
# NaT                     True
# NaT                     True
# NaT                     True
# NaT                     True
# NaT                     True
# Name: search_conducted, Length: 509681, dtype: bool

# %%
df.groupby(['search_conducted']).count()
# Out:
#                       id   state  stop_date  stop_time  location_raw  \
# search_conducted
# False             491909  491909     491909     491909        491909
# True               17762   17762      17762      17762         17762
#
#                   county_name  county_fips  fine_grained_location  \
# search_conducted
# False                       0            0                      0
# True                        0            0                      0
#
#                   police_department  driver_gender  ...  violation  \
# search_conducted                                    ...
# False                        491909         462822  ...     462846
# True                          17762          17762  ...      17762
#
#                   search_type_raw  search_type  contraband_found  \
# search_conducted
# False                           0            0            491909
# True                        17762        17762             17762
#
# ...

# %%
df.groupby(['search_conducted']).mean()
# Out:
#                   county_name  county_fips  fine_grained_location  \
# search_conducted
# False                     NaN          NaN                    NaN
# True                      NaN          NaN                    NaN
#
#                   driver_age_raw  driver_age  contraband_found  is_arrested  \
# search_conducted
# False                1970.206406    34.10987          0.000000     0.080257
# True                 1978.421462    30.66000          0.370397     0.348328
#
#                   drugs_related_stop
# search_conducted
# False                       0.000000
# True                        0.268269

# %%
df_copy.groupby(['search_conducted']).mean()
# Out:
#                   county_name  county_fips  fine_grained_location  \
# search_conducted
# False                     NaN          NaN                    NaN
# True                      NaN          NaN                    NaN
#
#                   driver_age_raw  driver_age  contraband_found  is_arrested  \
# search_conducted
# False                1970.206406    34.10987          0.000000     0.080257
# True                 1978.421462    30.66000          0.370189     0.348695
#
#                   drugs_related_stop
# search_conducted
# False                       0.000000
# True                        0.268118

# %%
df_f['search_conducted'].mean()
# Out:
# 0.018751239152648355

# %%
df_M['search_conducted'].mean()
# Out:
# 0.04379217389811301

# %%
df_copy = df.copy()

# %%
df_copy.groupby(['driver_gender']).mean()['search_conducted']
# Out:
# driver_gender
# F    0.018751
# M    0.043792
# Name: search_conducted, dtype: float64

# %%
df_copy.groupby(['violation', 'driver_gender']).mean()['search_conducted']
# Out:
# violation            driver_gender
# Equipment            F                0.040245
#                      M                0.070916
# Moving violation     F                0.038021
#                      M                0.059156
# Other                F                0.045898
#                      M                0.046120
# Registration/plates  F                0.054700
#                      M                0.103589
# Seat belt            F                0.017746
#                      M                0.031705
# Speeding             F                0.007738
#                      M                0.026630
# Name: search_conducted, dtype: float64

# %%
df_copy.groupby(['driver_gender', 'violation']).mean()['search_conducted']
# Out:
# driver_gender  violation
# F              Equipment              0.040245
#                Moving violation       0.038021
#                Other                  0.045898
#                Registration/plates    0.054700
#                Seat belt              0.017746
#                Speeding               0.007738
# M              Equipment              0.070916
#                Moving violation       0.059156
#                Other                  0.046120
#                Registration/plates    0.103589
#                Seat belt              0.031705
#                Speeding               0.026630
# Name: search_conducted, dtype: float64

# %%
df['search_type'].value_counts()
# Out:
# Incident to Arrest                                          6998
# Probable Cause                                              4989
# Reasonable Suspicion                                        1141
# Inventory                                                   1101
# Protective Frisk                                             879
# Incident to Arrest,Inventory                                 649
# Incident to Arrest,Probable Cause                            552
# Probable Cause,Reasonable Suspicion                          334
# Probable Cause,Protective Frisk                              221
# Incident to Arrest,Protective Frisk                          158
# Incident to Arrest,Inventory,Probable Cause                  151
# Inventory,Probable Cause                                     132
# Protective Frisk,Reasonable Suspicion                         83
# Incident to Arrest,Inventory,Protective Frisk                 77
# ...

# %%
def pfirsk(x):
    
    if 'Protective Frisk' in x:
        return True
    else:
        return False

# %%
pfirsk('fdgsj')
# Out:
# False

# %%
df.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
df_copy = df.copy()
df_copy['productive_frisk'] = df['search_type'].astype(str).apply(pfirsk)

# %%
df_copy['productive_frisk'].value_counts()
# Out:
# False    508083
# True       1598
# Name: productive_frisk, dtype: int64

# %%
df_copy['productive_frisk'].astype('bool')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 509676    False
# 509677    False
# 509678    False
# 509679    False
# 509680    False
# Name: productive_frisk, Length: 509681, dtype: bool

# %%
df_copy['productive_frisk'].dtype
# Out:
# dtype('bool')

# %%
df_copy[df_copy['search_conducted'] == True]['productive_frisk'].mean()
# Out:
# 0.08996734601959239

# %%
df_copy[df_copy['search_conducted'] == True].groupby(['driver_gender']).mean()['productive_frisk']
# Out:
# driver_gender
# F    0.042294
# M    0.050644
# Name: productive_frisk, dtype: float64

# %%
hourly_arrest_rate = df.groupby(['stop_time']).mean()['is_arrested']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hourly_arrest_rate)
plt.xlabel('Hour')
plt.ylabel('Arrested Rate')
# Out:
# Text(0, 0.5, 'Arrested Rate')

# %%
df_copy['stop_time'] = pd.to_datetime(df_copy['stop_time'])

# %%
df[['drugs_related_stop', 'stop_date']].groupby(['stop_date']).sum()
# Out:
#             drugs_related_stop
# stop_date
# 2005-01-02                 0.0
# 2005-01-04                 0.0
# 2005-01-06                 0.0
# 2005-01-12                 0.0
# 2005-01-18                 0.0
# ...                        ...
# 2015-12-27                 1.0
# 2015-12-28                 2.0
# 2015-12-29                 0.0
# 2015-12-30                 1.0
# 2015-12-31                 0.0
#
# [3809 rows x 1 columns]

# %%
df_year = df.copy()

# %%
df_year['year'] = pd.DatetimeIndex(df_year['stop_date']).year

# %%
df_year.groupby(['year']).sum()['drugs_related_stop']
# Out:
# year
# 2005.0    111.0
# 2006.0    368.0
# 2007.0    423.0
# 2008.0    344.0
# 2009.0    416.0
# 2010.0    400.0
# 2011.0    486.0
# 2012.0    596.0
# 2013.0    498.0
# 2014.0    644.0
# 2015.0    479.0
# Name: drugs_related_stop, dtype: float64

# %%
df_year.groupby(['year']).mean()['drugs_related_stop']
# Out:
# year
# 2005.0    0.007884
# 2006.0    0.006308
# 2007.0    0.007951
# 2008.0    0.007018
# 2009.0    0.009574
# 2010.0    0.009436
# 2011.0    0.010613
# 2012.0    0.009798
# 2013.0    0.011144
# 2014.0    0.012675
# 2015.0    0.010177
# Name: drugs_related_stop, dtype: float64

# %%
my_list = (df_year.groupby(['year'])['drugs_related_stop'].sum()).values.tolist()
annual_drug_rate = []
for i in range(len(my_list)-1):
    annual_drug_rate.append((my_list[i+1] - my_list[i])/my_list[i])
    print((2005 + i), (my_list[i+1] - my_list[i])/my_list[i])
# Out:
# 2005 2.315315315315315
# 2006 0.14945652173913043
# 2007 -0.1867612293144208
# 2008 0.20930232558139536
# 2009 -0.038461538461538464
# 2010 0.215
# 2011 0.22633744855967078
# 2012 -0.1644295302013423
# 2013 0.2931726907630522
# 2014 -0.2562111801242236

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(annual_drug_rate)
ax[1].plot(df_year.groupby(['year']).sum()['drugs_related_stop'])

# %%
df_year[['search_conducted', 'year']].groupby(['year']).sum()['search_conducted']
# Out:
# year
# 2005.0     700
# 2006.0    2097
# 2007.0    2098
# 2008.0    1802
# 2009.0    1985
# 2010.0    1660
# 2011.0    1610
# 2012.0    1860
# 2013.0    1218
# 2014.0    1474
# 2015.0    1258
# Name: search_conducted, dtype: int64

# %%
my_list = (df_year[['search_conducted', 'year']].groupby(['year']).sum()['search_conducted']).values.tolist()

# %%
annual_search_rate = []
for i in range(len(my_list)-1):
    print((2005 + i), ((my_list[i+1] - my_list[i])/my_list[i]))
    annual_search_rate.append((my_list[i+1] - my_list[i])/my_list[i])
# Out:
# 2005 1.9957142857142858
# 2006 0.0004768717215069146
# 2007 -0.14108674928503337
# 2008 0.10155382907880134
# 2009 -0.163727959697733
# 2010 -0.030120481927710843
# 2011 0.15527950310559005
# 2012 -0.34516129032258064
# 2013 0.21018062397372742
# 2014 -0.14654002713704206

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].plot(annual_drug_rate)
ax[0,0].set_title('annual_drug_rate')
ax[0,1].plot(df_year.groupby(['year']).sum()['drugs_related_stop'])
ax[0,1].set_title('drugs_related_stop')
ax[1,0].plot(annual_search_rate)
ax[1,0].set_title('annual_search_rate')
ax[1,1].plot(df_year[['search_conducted', 'year']].groupby(['year']).sum()['search_conducted'])
ax[1,1].set_title('search_conducted')
plt.tight_layout()

# %%
df_year.groupby(['year'])['drugs_related_stop'].sum()
# Out:
# year
# 2005.0    111.0
# 2006.0    368.0
# 2007.0    423.0
# 2008.0    344.0
# 2009.0    416.0
# 2010.0    400.0
# 2011.0    486.0
# 2012.0    596.0
# 2013.0    498.0
# 2014.0    644.0
# 2015.0    479.0
# Name: drugs_related_stop, dtype: float64

# %%
pd.crosstab(index=df['district'], columns=df['violation'])
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1         3788              7130   1502                  628          1
# Zone K2        11285             16440   5103                 4056       2898
# Zone K3        12959             16218   3929                 3871       3660
# Zone X1         1725              3711    752                  192        451
# Zone X3        11520             17179   4070                 3532       4446
# Zone X4        19975             29556   8865                 7551       4871
#
# violation  Speeding
# district
# Zone K1       33068
# Zone K2       57500
# Zone K3       68238
# Zone X1        6393
# Zone X3       48690
# Zone X4       54855

# %%
all_zones = pd.crosstab(index=df['district'], columns=df['violation'])

# %%
all_zones.loc['Zone K1':'Zone K3',:]
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1         3788              7130   1502                  628          1
# Zone K2        11285             16440   5103                 4056       2898
# Zone K3        12959             16218   3929                 3871       3660
#
# violation  Speeding
# district
# Zone K1       33068
# Zone K2       57500
# Zone K3       68238

# %%
k_zones = all_zones.loc['Zone K1':'Zone K3',:]

# %%
all_zones.plot.bar()

# %%
df[['district','violation']].groupby(['district']).count().plot.bar()

# %%
df[['district','violation']].groupby(['district']).count().loc['Zone K1':'Zone K3',:].plot.bar()

# %%
k_zones.plot.bar()

# %%
k_zones.plot(kind='bar', stacked=True)

# %%
def turner(x):
    if str(x).startswith('0'):
        return int(8)
    elif str(x).startswith('1'):
        return int(23)
    if str(x).startswith('3'):
        return int(45)

# %%
df_copy = df.copy()

# %%
df_copy['stop_duration']=df_copy['stop_duration'].apply(lambda x: turner(x))

# %%
df_copy['stop_duration'].unique()
# Out:
# array([ 8., 23., nan, 45.])

# %%
my_dict = dict(zip(df_copy['stop_duration'], df['stop_duration']))

# %%
type(df_copy['stop_duration'][0])
# Out:
# numpy.float64

# %%
df_copy= df_copy[(df_copy['stop_duration'] == 8.0) | (df_copy['stop_duration'] == 23.0) | (df_copy['stop_duration'] == 45.0)]

# %%
df_copy
# Out:
#                                 id state   stop_date stop_time location_raw  \
# stop_daytime
# 2005-01-02 01:55:00  RI-2005-00001    RI  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002    RI  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004    RI  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005    RI  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006    RI  2005-01-12     08:05      Zone X1
# ...                            ...   ...         ...       ...          ...
# 2015-12-31 22:46:00  RI-2015-47061    RI  2015-12-31     22:46      Zone X1
# 2015-12-31 22:47:00  RI-2015-47062    RI  2015-12-31     22:47      Zone X4
# 2015-12-31 23:08:00  RI-2015-47063    RI  2015-12-31     23:08      Zone X3
# 2015-12-31 23:44:00  RI-2015-47064    RI  2015-12-31     23:44      Zone K2
# 2015-12-31 23:48:00  RI-2015-47065    RI  2015-12-31     23:48      Zone K3
#
# ...

# %%
stop_length = df_copy[['violation_raw', 'stop_duration']].groupby(['violation_raw']).mean()['stop_duration']

# %%
stop_length.sort_values
# Out:
# <bound method Series.sort_values of violation_raw
# APB                                 18.593814
# Call for Service                    21.967670
# Equipment/Inspection Violation      11.454401
# Motorist Assist/Courtesy            17.620202
# Other Traffic Violation             13.834340
# Registration Violation              13.543268
# Seatbelt Violation                   9.697924
# Special Detail/Directed Patrol      14.876778
# Speeding                            10.589286
# Suspicious Person                   18.374269
# Violation of City/Town Ordinance    13.230695
# Warrant                             19.769231
# Name: stop_duration, dtype: float64>

# %%
stop_length.plot.barh()

# %%
df_we = pd.read_csv('police.csv')
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_we.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
df_w = pd.read_csv('weather.csv')

# %%
df_w.head()
# Out:
#        STATION        DATE  AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  WT04  \
# 0  USC00379423  2005-01-01   NaN   NaN  47.0  28.0   NaN   NaN   NaN   NaN
# 1  USC00379423  2005-01-02   NaN   NaN  52.0  24.0   NaN   NaN   NaN   NaN
# 2  USC00379423  2005-01-03   NaN   NaN  48.0  27.0   NaN   NaN   NaN   NaN
# 3  USC00379423  2005-01-04   NaN   NaN  54.0  40.0   NaN   NaN   NaN   NaN
# 4  USC00379423  2005-01-05   NaN   NaN  44.0  31.0   NaN   NaN   NaN   NaN
#
#    ...  WT11  WT13  WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 26 columns]

# %%
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8022 entries, 0 to 8021
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  8022 non-null   object
#  1   DATE     8022 non-null   object
#  2   AWND     4017 non-null   float64
#  3   TAVG     1217 non-null   float64
#  4   TMAX     8005 non-null   float64
#  5   TMIN     7996 non-null   float64
#  6   WT01     1777 non-null   float64
#  7   WT02     221 non-null    float64
#  8   WT03     227 non-null    float64
#  9   WT04     119 non-null    float64
#  10  WT05     360 non-null    float64
#  11  WT06     25 non-null     float64
#  12  WT07     79 non-null     float64
#  13  WT08     404 non-null    float64
#  14  WT09     69 non-null     float64
#  15  WT10     2 non-null      float64
#  16  WT11     3 non-null      float64
#  17  WT13     1175 non-null   float64
#  18  WT14     575 non-null    float64
#  19  WT15     6 non-null      float64
# ...

# %%
dff = df_w.set_index('DATE')
dff.head()
# Out:
#                 STATION  AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  WT04  WT05  \
# DATE
# 2005-01-01  USC00379423   NaN   NaN  47.0  28.0   NaN   NaN   NaN   NaN   NaN
# 2005-01-02  USC00379423   NaN   NaN  52.0  24.0   NaN   NaN   NaN   NaN   NaN
# 2005-01-03  USC00379423   NaN   NaN  48.0  27.0   NaN   NaN   NaN   NaN   NaN
# 2005-01-04  USC00379423   NaN   NaN  54.0  40.0   NaN   NaN   NaN   NaN   NaN
# 2005-01-05  USC00379423   NaN   NaN  44.0  31.0   NaN   NaN   NaN   NaN   NaN
#
#             ...  WT11  WT13  WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# DATE        ...
# 2005-01-01  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-02  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-03  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-04  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-05  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df_w[['TAVG','TMAX','TMIN']].describe()
# Out:
#               TAVG         TMAX         TMIN
# count  1217.000000  8005.000000  7996.000000
# mean     52.493016    61.247096    42.099425
# std      17.829792    18.495043    17.386667
# min       6.000000    13.000000   -10.000000
# 25%      39.000000    46.000000    29.000000
# 50%      54.000000    62.000000    42.000000
# 75%      68.000000    77.000000    57.000000
# max      86.000000   102.000000    77.000000

# %%
df_w[['TAVG','TMAX','TMIN']].plot.box()

# %%
sns.boxplot( data= df_w[['TAVG','TMAX','TMIN']])

# %%
df_w['TDIFF'] = df_w['TMAX'] - df_w['TMIN']

# %%
df_w['TDIFF'].describe()
# Out:
# count    7994.000000
# mean       19.149237
# std         7.009716
# min       -25.000000
# 25%        14.000000
# 50%        19.000000
# 75%        24.000000
# max        48.000000
# Name: TDIFF, dtype: float64

# %%
sns.distplot(df_w['TDIFF'], bins=20)

# %%
dff.loc['2005-01-01','WT01':'WT22']
# Out:
#             WT01  WT02  WT03  WT04  WT05  WT06  WT07  WT08  WT09  WT10  WT11  \
# DATE
# 2005-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-01   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#             WT13  WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# DATE
# 2005-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2005-01-01   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
df_wt=df_w.copy().loc[:,'WT01':'WT22']

# %%
df_wt['DATE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-268-96fee6d6c9d7> in <module>
# ----> 1 df_wt['DATE']
#
# ...

# %%
df_wt['bad_condition']=df_wt.sum(axis=1)

# %%
df_wt[['bad_condition']].fillna(0, inplace=True)
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df_wt.head()
# Out:
#    WT01  WT02  WT03  WT04  WT05  WT06  WT07  WT08  WT09  WT10  ...  WT13  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22  bad_condition
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN            0.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN            0.0
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN            0.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN            0.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN            0.0
#
# [5 rows x 21 columns]

# %%
sns.distplot(df_wt['bad_condition'])

# %%
df_wt.bad_condition.nunique()
# Out:
# 10

# %%
df_wt.bad_condition.unique()
# Out:
# array([0., 1., 2., 3., 4., 9., 6., 8., 5., 7.])

# %%
df_wt.bad_condition.value_counts()
# Out:
# 0.0    5738
# 1.0     628
# 4.0     476
# 3.0     380
# 2.0     368
# 5.0     282
# 6.0     101
# 7.0      41
# 8.0       4
# 9.0       4
# Name: bad_condition, dtype: int64

# %%
mapping = {0:"good",1:"bad",2:"bad",3:"bad",4:"bad",5:"worse",6:"worse",7:"worse",8:"worse",9:"worse"}

# %%
df_wt['rating']=df_wt['bad_condition'].astype(int).apply(lambda x:mapping[x])

# %%
df_wt.rating.value_counts()
# Out:
# good     5738
# bad      1852
# worse     432
# Name: rating, dtype: int64

# %%
my_list = ['good','bad','worse']
df_wt['rating']=df_wt['rating'].astype('category')

# %%
df_wt.rating
# Out:
# 0       good
# 1       good
# 2       good
# 3       good
# 4       good
#         ...
# 8017     bad
# 8018    good
# 8019     bad
# 8020     bad
# 8021     bad
# Name: rating, Length: 8022, dtype: category
# Categories (3, object): [bad, good, worse]

# %%
df_w['rating'] = df_wt['rating']

# %%
df_we_r = df_w[['DATE', 'rating']].copy()

# %%
df_we_r.iloc[4006]
# Out:
# DATE       2005-01-02 00:00:00
# rating                     bad
# index                     4006
# index_w                   4006
# Name: 4006, dtype: object

# %%
df_we_r.iloc[1]
# Out:
# DATE       2005-01-02 00:00:00
# rating                    good
# index                        1
# index_w                      1
# Name: 1, dtype: object

# %%
df_we_r.groupby(['rating']).count()
# Out:
#         DATE  index  index_w
# rating
# bad     1852   1852     1852
# good    5738   5738     5738
# worse    432    432      432

# %%
df_w['stop_date'] = df_w['DATE']

# %%
df.head(3)
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# ...

# %%
df.head()
# Out:
#               id state  stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI 2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI 2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI 2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI 2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI 2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
df_we_r.head()
# Out:
#          DATE rating
# 0  2005-01-01   good
# 1  2005-01-02   good
# 2  2005-01-03   good
# 3  2005-01-04   good
# 4  2005-01-05   good

# %%
df_we_r['DATE'] =pd.to_datetime(df_we_r['DATE'])

# %%
df['stop_date'] =pd.to_datetime(df['stop_date'])

# %%
df_we_r.DATE.value_counts()
# Out:
# 2012-05-25    3
# 2012-01-06    3
# 2011-06-28    3
# 2015-12-03    3
# 2015-12-11    3
#              ..
# 2007-04-16    1
# 2009-10-25    1
# 2011-10-10    1
# 2006-10-14    1
# 2005-07-31    1
# Name: DATE, Length: 4017, dtype: int64

# %%
df.stop_date.value_counts()
# Out:
# 2006-05-21    302
# 2015-09-05    302
# 2006-06-13    293
# 2012-01-08    292
# 2005-11-05    290
#              ...
# 2005-03-23      1
# 2005-07-06      1
# 2005-09-01      1
# 2005-05-21      1
# 2005-09-20      1
# Name: stop_date, Length: 3809, dtype: int64

# %%
pd.merge(df, df_we_r, left_on='stop_date', right_on='DATE', how='left')
# Out:
#                     id state  stop_date stop_time location_raw  county_name  \
# 0        RI-2005-00001    RI 2005-01-02     01:55      Zone K1          NaN
# 1        RI-2005-00001    RI 2005-01-02     01:55      Zone K1          NaN
# 2        RI-2005-00002    RI 2005-01-02     20:30      Zone X4          NaN
# 3        RI-2005-00002    RI 2005-01-02     20:30      Zone X4          NaN
# 4        RI-2005-00003    RI 2005-01-04     11:30      Zone X1          NaN
# ...                ...   ...        ...       ...          ...          ...
# 1018076       RI-NA-06    RI        NaT       NaN      Zone NA          NaN
# 1018077       RI-NA-07    RI        NaT       NaN      Zone NA          NaN
# 1018078       RI-NA-08    RI        NaT       NaN      Zone NA          NaN
# 1018079       RI-NA-09    RI        NaT       NaN      Zone NA          NaN
# 1018080       RI-NA-10    RI        NaT       NaN      Zone NA          NaN
#
# ...

# %%
df_merge.groupby([ 'stop_date']).mean()
# Out:
#             county_name  county_fips  fine_grained_location  driver_age_raw  \
# stop_date
# 2005-01-02          NaN          NaN                    NaN     1986.000000
# 2005-01-04          NaN          NaN                    NaN     1986.000000
# 2005-01-06          NaN          NaN                    NaN     1978.000000
# 2005-01-12          NaN          NaN                    NaN     1973.000000
# 2005-01-18          NaN          NaN                    NaN     1966.000000
# ...                 ...          ...                    ...             ...
# 2015-12-27          NaN          NaN                    NaN     1982.500000
# 2015-12-28          NaN          NaN                    NaN     1981.406250
# 2015-12-29          NaN          NaN                    NaN     1981.000000
# 2015-12-30          NaN          NaN                    NaN     1980.139130
# 2015-12-31          NaN          NaN                    NaN     1980.622222
#
# ...

# %%
df3.head()
# Out:
#               id state  stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI 2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00001    RI 2005-01-02     01:55      Zone K1          NaN
# 2  RI-2005-00002    RI 2005-01-02     20:30      Zone X4          NaN
# 3  RI-2005-00002    RI 2005-01-02     20:30      Zone X4          NaN
# 4  RI-2005-00003    RI 2005-01-04     11:30      Zone X1          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               600             M  ...
# 2          NaN                    NaN               500             M  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN                 0           NaN  ...
#
#    stop_duration  out_of_state drugs_related_stop district index_x index_x  \
# ...

# %%
# Out:
#         DATE rating  index
# 0 2005-01-01   good      0
# 1 2005-01-02   good      1
# 2 2005-01-03   good      2
# 3 2005-01-04   good      3
# 4 2005-01-05   good      4
